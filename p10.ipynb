# %%
import pandas as pd

# Replace 'your_data.csv' with the actual path to your CSV file
data = pd.read_csv('/content/drive/MyDrive/p10.csv')

# Explore the data (optional)
print(data.head())  # View the first few rows
print(data.info())  # Get information about data types, missing values, etc.

# Preprocess the data as needed (cleaning, transformations)
# ... (your data-specific preprocessing code)

# Save the prepared data in a format compatible with Power BI (e.g., CSV)
data.to_csv('processed_data.csv', index=False)
# Out:
#    Order ID Customer Name    Product Name  Quantity    Price  Order Date  \
# 0      1001    John Smith  T-Shirt (Blue)         2   $19.99  2024-04-10
# 1      1002      Jane Doe          Laptop         1  $899.99  2024-04-11
# 2      1003   Michael Lee      Coffee Mug         4    $5.99  2024-04-12
# 3      1004  Sarah Garcia      Headphones         1   $79.99  2024-04-12
# 4      1005     David Kim      Smartphone         1  $499.95  2024-04-13
#
#        City  Country
# 0  New York      USA
# 1    London       UK
# 2     Paris   France
# 3    Berlin  Germany
# 4     Tokyo    Japan
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8 non-null      int64
#  1   Customer Name  8 non-null      object
#  2   Product Name   8 non-null      object
#  3   Quantity       8 non-null      int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns  # For more advanced visualizations (optional)

# Example: Create a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Customer Name', y='Country', data=data)  # Replace with your column names
plt.xlabel('Column 1')
plt.ylabel('Column 2')
plt.title('Sample Scatter Plot')
plt.show()

# You can create additional plots (bar charts, histograms, etc.) based on your data
